# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/rahul/Desktop/GDSC-ML Tasks/New Dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv')
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
for column in df.columns:
    val_counts = df[column].value_counts()
    print(f"Column: {column}")
    print(f"Unique values: {val_counts}")
    print("\n")
# Out:
# Column: customerID
# Unique values: customerID
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: count, Length: 7043, dtype: int64
#
#
# Column: gender
# Unique values: gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
#
#
# Column: SeniorCitizen
# Unique values: SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
#
#
# Column: Partner
# Unique values: Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
#
# Column: Dependents
# Unique values: Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
#
# Column: tenure
# Unique values: tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
#
#
# Column: PhoneService
# Unique values: PhoneService
# ...

# %% [markdown]
# ## Data Cleaning:

# %%
df.loc[df['TotalCharges']==' ']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %%
df1 = df.copy()

# %%
#Handle missing values in TotalCharges
df1['TotalCharges'] = df1['TotalCharges'].replace(' ', np.nan)
df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'], errors='coerce')
df1['TotalCharges'] = df1['TotalCharges'].fillna(df1['TotalCharges'].median())

# %%
df1.drop(['customerID'],axis=1,inplace=True)

# %%
df1['SeniorCitizen'] = df1['SeniorCitizen'].replace({0: 'No', 1: 'Yes'})
df1.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            No     Yes         No       1           No
# 1    Male            No      No         No      34          Yes
# 2    Male            No      No         No       2          Yes
# 3    Male            No      No         No      45           No
# 4  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# ## Plotting Insights:

# %%
# Insight 1: Gender and Churn
plt.figure(figsize=(8, 6))
sns.countplot(data=df1, x='gender', hue='Churn',palette='Dark2',alpha=0.9)
plt.title('Churn by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 1. Gender and Churn
#
# ##### Insight: The churn rate between male and female customers appears to be fairly balanced, indicating that gender alone may not be a significant predictor of churn.
# ##### Explanation: The count plot visualizes the distribution of churn across genders, showing a roughly equal churn rate. This suggests that models like Logistic Regression or Random Forest, which rely on multiple features, may be more appropriate as gender alone won’t be sufficient to predict churn.

# %%
# Insight 2: Tenure and Churn
plt.figure(figsize=(8, 6))
sns.histplot(data=df1, x='tenure', hue='Churn', kde=True, bins=30, palette='Dark2',alpha =0.5,multiple='stack')
plt.title('Churn by Tenure')
plt.xlabel('Tenure (Months)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 2. Tenure and Churn
#
# ##### •	Insight: Customers with shorter tenure (less than 10 months) are more likely to churn, while those with longer tenure tend to stay.
# ##### •	Explanation: The histogram of tenure shows a high churn rate among customers who have been with the company for a shorter time. This pattern can suggest that tenure is an important feature for predicting churn. We could use this information to apply models like Decision Trees that can capture these non-linear relationships between tenure and churn.

# %%
# Insight 3: Monthly Charges and Churn
plt.figure(figsize=(8, 6))
sns.boxplot(data=df1, x='Churn', y='MonthlyCharges', palette='Dark2')
plt.title('Churn by Monthly Charges')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.show()
# Out:
# /var/folders/q6/0pfb75k55856k8_ms3tldx240000gn/T/ipykernel_737/2666436774.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df1, x='Churn', y='MonthlyCharges', palette='Dark2')

# %% [markdown]
# #### 3. Monthly Charges and Churn
#
# ##### •	Insight: Higher monthly charges are associated with a higher likelihood of churn.
# ##### •	Explanation: From the boxplot, we observe that customers who churn tend to have higher monthly charges. This can help in suggesting models such as XGBoost or Support Vector Machines (SVM), which can handle complex relationships between variables like monthly charges and churn.

# %%
# Insight 4: Contract Type and Churn
plt.figure(figsize=(8, 6))
sns.countplot(data=df1, x='Contract', hue='Churn', palette='Dark2')
plt.title('Churn by Contract Type')
plt.xlabel('Contract Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 4. Contract Type and Churn
#
# ##### •	Insight: Customers with month-to-month contracts are more likely to churn compared to those with one or two-year contracts.
# ##### •	Explanation: The count plot shows a much higher churn rate for month-to-month contracts. This indicates that the type of contract a customer holds could be a strong predictor of churn. This feature could be especially useful in a Random Forest model where categorical data has a strong predictive power.

# %%
# Insight 5: Internet Service Type and Churn
plt.figure(figsize=(8, 6))
sns.countplot(data=df1, x='InternetService', hue='Churn', palette='Dark2')
plt.title('Churn by Internet Service Type')
plt.xlabel('Internet Service Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 5. Internet Service Type and Churn
#
# ##### •	Insight: Fiber optic customers are more likely to churn compared to those using DSL or no internet service.
# ##### •	Explanation: The count plot reveals that customers using fiber optic internet service have a higher churn rate. This suggests that the quality or satisfaction with fiber optic services may need attention. A Gradient Boosting model could be useful here, as it can effectively deal with categorical variables like internet service.

# %%
# Insight 6: Total Charges and Churn
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')  # Convert TotalCharges to numeric, handling errors
plt.figure(figsize=(8, 6))
sns.histplot(data=df1, x='TotalCharges', hue='Churn', kde=False, bins=30, palette='Dark2',alpha=0.5,multiple='stack')
plt.title('Churn by Total Charges')
plt.xlabel('Total Charges')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 6. Total Charges and Churn
#
# ##### •	Insight: Churn is more prevalent among customers with lower total charges, indicating that new customers or those with fewer services may be more likely to leave.
# ##### •	Explanation: The distribution plot shows that churned customers often have lower total charges. This feature can provide valuable input to models like Logistic Regression, especially if the relationship between total charges and churn is linear, as well as non-linear models like Decision Trees.

# %%
# Plot: Senior Citizens and Contract Types
plt.figure(figsize=(8,6))
sns.countplot(x='Contract', hue='SeniorCitizen', data=df1, palette='Set2')
plt.title('Contract Types Preferred by Senior Citizens')
plt.show()

# %%
# Combine services to show multiple service subscriptions
df['MultipleServices'] = df.apply(lambda row: 'Multiple' if row['OnlineSecurity'] == 'Yes' and row['TechSupport'] == 'Yes' else 'Single', axis=1)

# Plot: Multiple Services vs Churn
plt.figure(figsize=(8,6))
sns.countplot(x='MultipleServices', hue='Churn', data=df, palette='coolwarm')
plt.title('Churn Rates for Customers with Multiple Services')
plt.show()

# %%
# Plot: Dependents vs Monthly Charges
plt.figure(figsize=(8,6))
sns.boxplot(x='Dependents', y='MonthlyCharges', data=df, palette='Set3')
plt.title('Dependents and Monthly Charges')
plt.show()
# Out:
# /var/folders/q6/0pfb75k55856k8_ms3tldx240000gn/T/ipykernel_737/3900138236.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dependents', y='MonthlyCharges', data=df, palette='Set3')

# %%
# Plot: Streaming Services vs Monthly Charges
df['StreamingBoth'] = df.apply(lambda x: 'Yes' if x['StreamingTV'] == 'Yes' and x['StreamingMovies'] == 'Yes' else 'No', axis=1)

plt.figure(figsize=(8,6))
sns.boxplot(x='StreamingBoth', y='MonthlyCharges', data=df, palette='Blues')
plt.title('Streaming Services and Monthly Charges')
plt.show()
# Out:
# /var/folders/q6/0pfb75k55856k8_ms3tldx240000gn/T/ipykernel_737/890922524.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='StreamingBoth', y='MonthlyCharges', data=df, palette='Blues')

# %%
# Plot: Paperless Billing vs Contract Type
plt.figure(figsize=(8,6))
sns.countplot(x='Contract', hue='PaperlessBilling', data=df, palette='cividis')
plt.title('Paperless Billing Across Contract Types')
plt.show()

# %%
# Plot: Tech Support vs Churn
plt.figure(figsize=(8,6))
sns.countplot(x='TechSupport', hue='Churn', data=df, palette='Reds')
plt.title('Tech Support Subscription and Churn Rate')
plt.show()

# %%
# Plot: Total Charges vs Tenure
plt.figure(figsize=(8,6))
sns.scatterplot(x='tenure', y='TotalCharges', hue='Churn', data=df, palette='Spectral')
plt.title('Total Charges vs Tenure with Churn Indication')
plt.show()

# %%
# Plot: Gender vs Monthly Charges
plt.figure(figsize=(8,6))
sns.boxplot(x='gender', y='MonthlyCharges', data=df, palette='Set1')
plt.title('Gender and Monthly Charges')
plt.show()
# Out:
# /var/folders/q6/0pfb75k55856k8_ms3tldx240000gn/T/ipykernel_737/263691016.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='gender', y='MonthlyCharges', data=df, palette='Set1')

# %%
# Plot: Senior Citizen and Payment Method
plt.figure(figsize=(8,6))
sns.countplot(x='PaymentMethod', hue='SeniorCitizen', data=df, palette='Set3')
plt.title('Senior Citizens and Payment Methods')
plt.xticks(rotation=45)
plt.show()

# %%
# Plot: Internet Service vs Tenure
plt.figure(figsize=(8,6))
sns.boxplot(x='InternetService', y='tenure', data=df, palette='magma')
plt.title('Internet Service and Tenure')
plt.show()
# Out:
# /var/folders/q6/0pfb75k55856k8_ms3tldx240000gn/T/ipykernel_737/3899178861.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='InternetService', y='tenure', data=df, palette='magma')
